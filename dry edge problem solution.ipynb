# %%
a=np.array([1,1.2,1.2,1.4,1.5,1.4,1.3,1,2,2,1.2,1.3,1.5,1.7,1.7,1.5,1.2,1.4,2,1,1])
b=np.array([1,1.5,1.1,1.2,1.5,1.5,1.1,1.2,1,2.1,1,1.2,1.5,1.2,1.2,1.255,4.2,1.5,1.5,1.2,1.5])
data=a,b
data
# Out:
# (array([1. , 1.2, 1.2, 1.4, 1.5, 1.4, 1.3, 1. , 2. , 2. , 1.2, 1.3, 1.5,
#         1.7, 1.7, 1.5, 1.2, 1.4, 2. , 1. , 1. ]),
#  array([1.   , 1.5  , 1.1  , 1.2  , 1.5  , 1.5  , 1.1  , 1.2  , 1.   ,
#         2.1  , 1.   , 1.2  , 1.5  , 1.2  , 1.2  , 1.255, 4.2  , 1.5  ,
#         1.5  , 1.2  , 1.5  ]))

# %%
import matplotlib.pyplot as plt
plt.scatter(a,b)

# %%
import numpy as np
import pandas as pd

# %%
table=pd.DataFrame({'a':a,"b":b})
table
# Out:
#       a      b
# 0   1.0  1.000
# 1   1.2  1.500
# 2   1.2  1.100
# 3   1.4  1.200
# 4   1.5  1.500
# 5   1.4  1.500
# 6   1.3  1.100
# 7   1.0  1.200
# 8   2.0  1.000
# 9   2.0  2.100
# 10  1.2  1.000
# 11  1.3  1.200
# 12  1.5  1.500
# 13  1.7  1.200
# 14  1.7  1.200
# 15  1.5  1.255
# 16  1.2  4.200
# 17  1.4  1.500
# 18  2.0  1.500
# 19  1.0  1.200
# 20  1.0  1.500

# %%
sort=table.sort_values(by=['a'],ascending=False)
sort
# Out:
#       a      b
# 9   2.0  2.100
# 8   2.0  1.000
# 18  2.0  1.500
# 14  1.7  1.200
# 13  1.7  1.200
# 15  1.5  1.255
# 4   1.5  1.500
# 12  1.5  1.500
# 17  1.4  1.500
# 5   1.4  1.500
# 3   1.4  1.200
# 11  1.3  1.200
# 6   1.3  1.100
# 1   1.2  1.500
# 2   1.2  1.100
# 16  1.2  4.200
# 10  1.2  1.000
# 19  1.0  1.200
# 0   1.0  1.000
# 7   1.0  1.200
# 20  1.0  1.500

# %%
result=sort.drop_duplicates('a',keep='last').values
result
# Out:
# array([[1. , 1.5],
#        [1.2, 1.5],
#        [1.3, 1.2],
#        [1.4, 1.2],
#        [1.5, 1.5],
#        [1.7, 1.2],
#        [2. , 1.5]])

# %%
r1=sort.groupby(['a']).head(2)
r1
# Out:
#       a      b
# 9   2.0  2.100
# 8   2.0  1.000
# 14  1.7  1.200
# 13  1.7  1.200
# 15  1.5  1.255
# 4   1.5  1.500
# 17  1.4  1.500
# 5   1.4  1.500
# 11  1.3  1.200
# 6   1.3  1.100
# 1   1.2  1.500
# 2   1.2  1.100
# 19  1.0  1.200
# 0   1.0  1.000

# %%
# Out:
# (14, 2)
