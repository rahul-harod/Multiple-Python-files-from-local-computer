# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
bhopal=pd.read_csv(r'E:\plot\bhopal_MP.csv')
coimbatur_tamilnadu=pd.read_csv(r'E:\plot\coimbatur_tamilnadu.csv')
jodhpur_rajasthan=pd.read_csv(r'E:\plot\jodhpur_rajasthan.csv')
kolkata=pd.read_csv(r'E:\plot\kolkata.csv')
mumbai=pd.read_csv(r'E:\plot\mumbai.csv')
nainital_Uttrakhand=pd.read_csv(r'E:\plot\nainital_Uttrakhand.csv')

# %%
bhopal_x=bhopal['system:time_start']
bhopal_y=bhopal['LST']
coimbatur_tamilnadu_x=coimbatur_tamilnadu['system:time_start']
coimbatur_tamilnadu_y=coimbatur_tamilnadu['LST']
jodhpur_rajasthan_x=jodhpur_rajasthan['system:time_start']
jodhpur_rajasthan_y=jodhpur_rajasthan['LST']
kolkata_x=kolkata['system:time_start']
kolkata_y=kolkata['LST']
mumbai_x=mumbai['system:time_start']
mumbai_y=mumbai['LST']
nainital_Uttrakhand_x=nainital_Uttrakhand['system:time_start']
nainital_Uttrakhand_y=nainital_Uttrakhand['LST']

# %%
fig,((axs1,axs2,axs3),(axs4,axs5,axs6))=plt.subplots(2,3,figsize=(15,5))
axs1.plot(bhopal_x,bhopal_y)
axs1.set_xlabel('Date',fontsize =11)
axs1.set_ylabel('LST (K)',fontsize =11)
# Out:
# Text(0, 0.5, 'LST (K)')
